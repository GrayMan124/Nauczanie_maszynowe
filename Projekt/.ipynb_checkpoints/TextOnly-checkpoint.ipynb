# %%
import torch
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt
from torchvision.transforms import Normalize
from collections import namedtuple

torch.cuda.is_available()
from utils import correct
from utils import Lang
from utils import return_fun
import utils

# %%
reuters=pd.read_csv("data/reut_data.csv",sep='|')

sx5e_data=pd.read_csv("data\SX5E.csv")

# %%
reuters.drop(columns='column1',inplace=True)

# %%
reuters.drop_duplicates(subset ="Headline",
                     keep = 'first', inplace = True)
reuters.dropna(inplace=True)

# %%
sx5e_data['Date']=pd.to_datetime(sx5e_data.Date)
sx5e_data = sx5e_data.sort_index(axis=0 ,ascending=False)
sx5e_data.reset_index(drop=True,inplace=True)

# %%
sx5e_data.head()
# Out:
#         Date    Close
# 0 2021-12-10  4199.16
# 1 2021-12-09  4208.30
# 2 2021-12-08  4233.09
# 3 2021-12-07  4276.20
# 4 2021-12-06  4137.11

# %%
reuters.head()
# Out:
#          Date                                           Headline
# 0  2021-12-10  REFILE-UPDATE 2-European stocks slip on Omicro...
# 1  2021-12-10  Tech stocks drag European shares ahead of U.S....
# 2  2021-12-09  UPDATE 2-European shares fall again on Omicron...
# 3  2021-12-09  European shares rebound as vaccine reassurance...
# 4  2021-12-08  UPDATE 2-European shares end lower as tech, lu...

# %%
reuters.dropna(inplace=True)
reuters.reset_index(drop=False,inplace=True)

# %%
for i in range(len(reuters)):
    text=reuters['Headline'][i]
    text=text.replace("REFILE-UPDATE 2-","")
    text=text.replace("UPDATE 2-","")
    text=text.replace("UPDATE 1-","")
    text=text.replace("UPDATE ","")
    text=text.replace(",","")
    text=text.replace(".","")
    text=text.replace(";","")
    text=text.replace(":","")
    text=text.replace("-","")
    text=text.replace("European","")
    reuters['Headline'][i]=text
# Out:
# <ipython-input-11-4fffbfdca2bc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reuters['Headline'][i]=text

# %%
sx5e_data.drop(columns=[' Open',' High',' Low'],inplace=True)

# %%
ret_fun=return_fun(sx5e_data,1,1)

# %%
sx5e_data['Return']=ret_fun

# %%
sx5e_data.dropna(inplace=True)
sx5e_data.head()
# Out:
#         Date    Close    Return
# 0 2021-12-10  4199.16  0.217663
# 1 2021-12-09  4208.30  0.589074
# 2 2021-12-08  4233.09  1.018405
# 3 2021-12-07  4276.20 -3.252654
# 4 2021-12-06  4137.11 -1.376807

# %%
ret_fun.remove(None)
tensor_ret=torch.tensor(ret_fun,dtype=torch.float32)
mean_ret=torch.mean(tensor_ret)
std_ret=torch.std(tensor_ret)
ret_norm=(tensor_ret-mean_ret)/std_ret

# %%
lang=Lang('t')
for i in range(len(reuters)):
    sentence=reuters['Headline'][i]
    lang.addSentence(sentence)

# %%
data_set=[]
data=namedtuple('Data',['headline','ret'])
for i in range(len(reuters)):
    headline=utils.tensorFromSentence(lang,reuters['Headline'][i])
    row=sx5e_data.loc[sx5e_data['Date']== reuters['Date'][i]]
    ret=row['Return']
    if(ret.empty):
        continue
    ret=torch.tensor(ret.values)
    r=(ret-mean_ret)/std_ret
    d=data(headline,r)
    data_set.append(d)

# %%
len(data_set)
# Out:
# 12656

# %%
train_data=data_set[3232:]
val_data=data_set[1616:3232]
test_data=data_set[:1616]
print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 9424
# 1616
# 1616

# %%
train_loader=torch.utils.data.DataLoader(train_data, batch_size=1,shuffle=True)
val_loader=torch.utils.data.DataLoader(val_data, batch_size=1)
test_loader=torch.utils.data.DataLoader(test_data, batch_size=1)

# %%
from utils import TextOnlyGRU

# %%
text_only_gru=TextOnlyGRU(lang.n_words,256,128,1).cuda()
params = text_only_gru.parameters()

loss_fn=torch.nn.MSELoss()
optimizer = torch.optim.Adam(params, lr=0.01) 
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)


epoch = 30


history_train_loss=[]
history_val_loss=[]

history_train_acc=[]
history_val_acc=[]


for e in range(1,epoch+1):    
   
    corr=0
    text_only_gru.train()
    loss_buffer=[]
    for i, (x, y) in enumerate(train_loader):
        size+=len(y)
        x = x.cuda()
        y = y.cuda()
        optimizer.zero_grad()
        
        output = text_only_gru(x)
        output= output.float()
        y=y.float()
        loss = loss_fn(output, y)
        corr+=correct(output,y,std_ret,mean_ret)
        loss_buffer.append(loss.item())
        loss.backward()
        optimizer.step() 
        
        if(i%1000==1):
            print(f"Epoch: {e} Progress: {100 * i/len(train_loader):2.0f}% Loss: {torch.mean(torch.tensor(loss_buffer)):.3f}")
    
    scheduler.step()
    
    train_loss=torch.mean(torch.tensor(loss_buffer))
    history_train_loss.append(train_loss)
    train_acc=corr/len(train_loader)
    history_train_acc.append(train_acc)
    
    print()
    print(f"Epoch:  {e}  Train Loss:  {train_loss:.3f} Train Acc: {train_acc:.5f}")
    
    
    text_only_gru.eval()
    with torch.no_grad():
        val_loss_buffer=[]
        val_ac=0
        cor=0
        for i, (x,y) in enumerate(val_loader):
            x=x.cuda()
            y=y.cuda()
            
            output=text_only_gru(x)
            output.float()
            y.float()
            val_loss_buffer.append(loss_fn(output,y).item())
            
            
            cor+=correct(output,y,std_ret,mean_ret)
            
        val_acc=cor/len(val_loader)
        val_loss=torch.mean(torch.tensor(val_loss_buffer))
        print(f"Val loss: {val_loss:.3f} Val Acc {val_acc:.5f}")
        print()
        
        history_val_loss.append(val_loss)
        history_val_acc.append(val_acc)
# Out:
# Epoch: 1 Progress:  0% Loss: 0.534
# Epoch: 1 Progress: 11% Loss: 1.270
# Epoch: 1 Progress: 21% Loss: 1.242
# Epoch: 1 Progress: 32% Loss: 1.261
# Epoch: 1 Progress: 42% Loss: 1.287
# Epoch: 1 Progress: 53% Loss: 1.272
# Epoch: 1 Progress: 64% Loss: 1.259
# Epoch: 1 Progress: 74% Loss: 1.243
# Epoch: 1 Progress: 85% Loss: 1.262
# Epoch: 1 Progress: 96% Loss: 1.268
#
# Epoch:  1  Train Loss:  1.266 Train Acc: 0.49873
# Val loss: 1.026 Val Acc 0.50990
#
# Epoch: 2 Progress:  0% Loss: 0.553
# Epoch: 2 Progress: 11% Loss: 1.331
# Epoch: 2 Progress: 21% Loss: 1.326
# Epoch: 2 Progress: 32% Loss: 1.239
# Epoch: 2 Progress: 42% Loss: 1.271
# Epoch: 2 Progress: 53% Loss: 1.286
# Epoch: 2 Progress: 64% Loss: 1.274
# Epoch: 2 Progress: 74% Loss: 1.265
# Epoch: 2 Progress: 85% Loss: 1.259
# Epoch: 2 Progress: 96% Loss: 1.244
#
# Epoch:  2  Train Loss:  1.251 Train Acc: 0.49979
# Val loss: 0.989 Val Acc 0.51052
#
# Epoch: 3 Progress:  0% Loss: 0.156
# Epoch: 3 Progress: 11% Loss: 1.181
# Epoch: 3 Progress: 21% Loss: 1.295
# Epoch: 3 Progress: 32% Loss: 1.256
# Epoch: 3 Progress: 42% Loss: 1.223
# Epoch: 3 Progress: 53% Loss: 1.235
# Epoch: 3 Progress: 64% Loss: 1.239
# Epoch: 3 Progress: 74% Loss: 1.247
# Epoch: 3 Progress: 85% Loss: 1.260
# Epoch: 3 Progress: 96% Loss: 1.246
#
# Epoch:  3  Train Loss:  1.239 Train Acc: 0.49629
# Val loss: 1.144 Val Acc 0.51856
#
# Epoch: 4 Progress:  0% Loss: 0.415
# Epoch: 4 Progress: 11% Loss: 1.290
# Epoch: 4 Progress: 21% Loss: 1.230
# Epoch: 4 Progress: 32% Loss: 1.231
# Epoch: 4 Progress: 42% Loss: 1.248
# Epoch: 4 Progress: 53% Loss: 1.219
# Epoch: 4 Progress: 64% Loss: 1.224
# Epoch: 4 Progress: 74% Loss: 1.238
# Epoch: 4 Progress: 85% Loss: 1.231
# Epoch: 4 Progress: 96% Loss: 1.219
#
# Epoch:  4  Train Loss:  1.224 Train Acc: 0.50764
# Val loss: 1.417 Val Acc 0.49691
#
# Epoch: 5 Progress:  0% Loss: 1.485
# Epoch: 5 Progress: 11% Loss: 1.244
# Epoch: 5 Progress: 21% Loss: 1.207
# Epoch: 5 Progress: 32% Loss: 1.233
# Epoch: 5 Progress: 42% Loss: 1.231
# Epoch: 5 Progress: 53% Loss: 1.240
# Epoch: 5 Progress: 64% Loss: 1.244
# Epoch: 5 Progress: 74% Loss: 1.238
# Epoch: 5 Progress: 85% Loss: 1.209
# Epoch: 5 Progress: 96% Loss: 1.212
#
# Epoch:  5  Train Loss:  1.209 Train Acc: 0.50891
# Val loss: 1.112 Val Acc 0.51485
#
# Epoch: 6 Progress:  0% Loss: 0.239
# Epoch: 6 Progress: 11% Loss: 1.166
# Epoch: 6 Progress: 21% Loss: 1.200
# Epoch: 6 Progress: 32% Loss: 1.199
# Epoch: 6 Progress: 42% Loss: 1.187
# Epoch: 6 Progress: 53% Loss: 1.161
# Epoch: 6 Progress: 64% Loss: 1.172
# Epoch: 6 Progress: 74% Loss: 1.195
# Epoch: 6 Progress: 85% Loss: 1.206
# Epoch: 6 Progress: 96% Loss: 1.214
#
# Epoch:  6  Train Loss:  1.204 Train Acc: 0.50785
# Val loss: 1.002 Val Acc 0.48886
#
# Epoch: 7 Progress:  0% Loss: 0.376
# Epoch: 7 Progress: 11% Loss: 1.165
# Epoch: 7 Progress: 21% Loss: 1.177
# Epoch: 7 Progress: 32% Loss: 1.177
# Epoch: 7 Progress: 42% Loss: 1.181
# Epoch: 7 Progress: 53% Loss: 1.190
# Epoch: 7 Progress: 64% Loss: 1.177
# Epoch: 7 Progress: 74% Loss: 1.182
# Epoch: 7 Progress: 85% Loss: 1.186
# Epoch: 7 Progress: 96% Loss: 1.197
#
# Epoch:  7  Train Loss:  1.196 Train Acc: 0.50446
# Val loss: 1.058 Val Acc 0.50619
#
# Epoch: 8 Progress:  0% Loss: 1.218
# Epoch: 8 Progress: 11% Loss: 1.211
# Epoch: 8 Progress: 21% Loss: 1.201
# Epoch: 8 Progress: 32% Loss: 1.218
# Epoch: 8 Progress: 42% Loss: 1.226
# Epoch: 8 Progress: 53% Loss: 1.203
# Epoch: 8 Progress: 64% Loss: 1.189
# Epoch: 8 Progress: 74% Loss: 1.205
# Epoch: 8 Progress: 85% Loss: 1.201
# Epoch: 8 Progress: 96% Loss: 1.186
#
# Epoch:  8  Train Loss:  1.181 Train Acc: 0.50435
# Val loss: 1.001 Val Acc 0.51176
#
# Epoch: 9 Progress:  0% Loss: 0.148
# Epoch: 9 Progress: 11% Loss: 1.200
# Epoch: 9 Progress: 21% Loss: 1.202
# Epoch: 9 Progress: 32% Loss: 1.226
# Epoch: 9 Progress: 42% Loss: 1.197
# Epoch: 9 Progress: 53% Loss: 1.180
# Epoch: 9 Progress: 64% Loss: 1.190
# Epoch: 9 Progress: 74% Loss: 1.181
# Epoch: 9 Progress: 85% Loss: 1.175
# Epoch: 9 Progress: 96% Loss: 1.173
#
# Epoch:  9  Train Loss:  1.170 Train Acc: 0.50106
# Val loss: 1.396 Val Acc 0.50743
#
# Epoch: 10 Progress:  0% Loss: 0.949
# Epoch: 10 Progress: 11% Loss: 1.168
# Epoch: 10 Progress: 21% Loss: 1.142
# Epoch: 10 Progress: 32% Loss: 1.176
# Epoch: 10 Progress: 42% Loss: 1.179
# Epoch: 10 Progress: 53% Loss: 1.169
# Epoch: 10 Progress: 64% Loss: 1.162
# Epoch: 10 Progress: 74% Loss: 1.173
# Epoch: 10 Progress: 85% Loss: 1.169
# Epoch: 10 Progress: 96% Loss: 1.171
#
# Epoch:  10  Train Loss:  1.165 Train Acc: 0.51114
# Val loss: 1.005 Val Acc 0.49876
#
# Epoch: 11 Progress:  0% Loss: 3.493
# Epoch: 11 Progress: 11% Loss: 1.198
# Epoch: 11 Progress: 21% Loss: 1.174
# Epoch: 11 Progress: 32% Loss: 1.151
# Epoch: 11 Progress: 42% Loss: 1.153
# Epoch: 11 Progress: 53% Loss: 1.145
# Epoch: 11 Progress: 64% Loss: 1.142
# Epoch: 11 Progress: 74% Loss: 1.157
# Epoch: 11 Progress: 85% Loss: 1.159
# Epoch: 11 Progress: 96% Loss: 1.158
#
# Epoch:  11  Train Loss:  1.162 Train Acc: 0.50393
# Val loss: 1.109 Val Acc 0.50186
#
# Epoch: 12 Progress:  0% Loss: 2.205
# Epoch: 12 Progress: 11% Loss: 1.054
# Epoch: 12 Progress: 21% Loss: 1.117
# Epoch: 12 Progress: 32% Loss: 1.136
# Epoch: 12 Progress: 42% Loss: 1.142
# Epoch: 12 Progress: 53% Loss: 1.120
# Epoch: 12 Progress: 64% Loss: 1.151
# Epoch: 12 Progress: 74% Loss: 1.140
# Epoch: 12 Progress: 85% Loss: 1.148
# Epoch: 12 Progress: 96% Loss: 1.156
#
# Epoch:  12  Train Loss:  1.155 Train Acc: 0.50212
# Val loss: 1.187 Val Acc 0.50000
#
# Epoch: 13 Progress:  0% Loss: 1.339
# Epoch: 13 Progress: 11% Loss: 1.102
# Epoch: 13 Progress: 21% Loss: 1.052
# Epoch: 13 Progress: 32% Loss: 1.104
# Epoch: 13 Progress: 42% Loss: 1.102
# Epoch: 13 Progress: 53% Loss: 1.124
# Epoch: 13 Progress: 64% Loss: 1.140
# Epoch: 13 Progress: 74% Loss: 1.135
# Epoch: 13 Progress: 85% Loss: 1.139
# Epoch: 13 Progress: 96% Loss: 1.142
#
# Epoch:  13  Train Loss:  1.149 Train Acc: 0.50212
# Val loss: 1.033 Val Acc 0.49814
#
# Epoch: 14 Progress:  0% Loss: 0.028
# Epoch: 14 Progress: 11% Loss: 1.034
# Epoch: 14 Progress: 21% Loss: 1.023
# Epoch: 14 Progress: 32% Loss: 1.061
# Epoch: 14 Progress: 42% Loss: 1.082
# Epoch: 14 Progress: 53% Loss: 1.119
# Epoch: 14 Progress: 64% Loss: 1.132
# Epoch: 14 Progress: 74% Loss: 1.139
# Epoch: 14 Progress: 85% Loss: 1.136
# Epoch: 14 Progress: 96% Loss: 1.143
#
# Epoch:  14  Train Loss:  1.139 Train Acc: 0.50923
# Val loss: 1.029 Val Acc 0.50928
#
# Epoch: 15 Progress:  0% Loss: 0.251
# Epoch: 15 Progress: 11% Loss: 1.128
# Epoch: 15 Progress: 21% Loss: 1.100
# Epoch: 15 Progress: 32% Loss: 1.129
# Epoch: 15 Progress: 42% Loss: 1.124
# Epoch: 15 Progress: 53% Loss: 1.134
# Epoch: 15 Progress: 64% Loss: 1.140
# Epoch: 15 Progress: 74% Loss: 1.151
# Epoch: 15 Progress: 85% Loss: 1.147
# Epoch: 15 Progress: 96% Loss: 1.128
#
# Epoch:  15  Train Loss:  1.133 Train Acc: 0.51846
# Val loss: 1.007 Val Acc 0.52228
#
# Epoch: 16 Progress:  0% Loss: 0.947
# Epoch: 16 Progress: 11% Loss: 0.964
# Epoch: 16 Progress: 21% Loss: 1.170
# Epoch: 16 Progress: 32% Loss: 1.149
# Epoch: 16 Progress: 42% Loss: 1.133
# Epoch: 16 Progress: 53% Loss: 1.125
# Epoch: 16 Progress: 64% Loss: 1.134
# Epoch: 16 Progress: 74% Loss: 1.146
# Epoch: 16 Progress: 85% Loss: 1.146
# Epoch: 16 Progress: 96% Loss: 1.141
#
# Epoch:  16  Train Loss:  1.133 Train Acc: 0.50456
# Val loss: 1.001 Val Acc 0.50186
#
# Epoch: 17 Progress:  0% Loss: 0.221
# Epoch: 17 Progress: 11% Loss: 1.069
# Epoch: 17 Progress: 21% Loss: 1.092
# Epoch: 17 Progress: 32% Loss: 1.096
# Epoch: 17 Progress: 42% Loss: 1.112
# Epoch: 17 Progress: 53% Loss: 1.117
# Epoch: 17 Progress: 64% Loss: 1.132
# Epoch: 17 Progress: 74% Loss: 1.130
# Epoch: 17 Progress: 85% Loss: 1.137
# Epoch: 17 Progress: 96% Loss: 1.133
#
# Epoch:  17  Train Loss:  1.130 Train Acc: 0.51761
# Val loss: 0.996 Val Acc 0.52290
#
# Epoch: 18 Progress:  0% Loss: 0.385
# Epoch: 18 Progress: 11% Loss: 1.073
# Epoch: 18 Progress: 21% Loss: 1.072
# Epoch: 18 Progress: 32% Loss: 1.103
# Epoch: 18 Progress: 42% Loss: 1.109
# Epoch: 18 Progress: 53% Loss: 1.099
# Epoch: 18 Progress: 64% Loss: 1.113
# Epoch: 18 Progress: 74% Loss: 1.129
# Epoch: 18 Progress: 85% Loss: 1.137
# Epoch: 18 Progress: 96% Loss: 1.128
#
# Epoch:  18  Train Loss:  1.127 Train Acc: 0.51220
# Val loss: 1.017 Val Acc 0.50186
#
# Epoch: 19 Progress:  0% Loss: 0.956
# Epoch: 19 Progress: 11% Loss: 1.103
# Epoch: 19 Progress: 21% Loss: 1.149
# Epoch: 19 Progress: 32% Loss: 1.184
# Epoch: 19 Progress: 42% Loss: 1.135
# Epoch: 19 Progress: 53% Loss: 1.160
# Epoch: 19 Progress: 64% Loss: 1.168
# Epoch: 19 Progress: 74% Loss: 1.159
# Epoch: 19 Progress: 85% Loss: 1.154
# Epoch: 19 Progress: 96% Loss: 1.132
#
# Epoch:  19  Train Loss:  1.130 Train Acc: 0.51072
# Val loss: 1.004 Val Acc 0.49814
#
# Epoch: 20 Progress:  0% Loss: 0.914
# Epoch: 20 Progress: 11% Loss: 1.167
# Epoch: 20 Progress: 21% Loss: 1.102
# Epoch: 20 Progress: 32% Loss: 1.197
# Epoch: 20 Progress: 42% Loss: 1.149
# Epoch: 20 Progress: 53% Loss: 1.112
# Epoch: 20 Progress: 64% Loss: 1.103
# Epoch: 20 Progress: 74% Loss: 1.115
# Epoch: 20 Progress: 85% Loss: 1.119
# Epoch: 20 Progress: 96% Loss: 1.123
#
# Epoch:  20  Train Loss:  1.122 Train Acc: 0.50944
# Val loss: 0.990 Val Acc 0.51795
#
# Epoch: 21 Progress:  0% Loss: 0.774
# Epoch: 21 Progress: 11% Loss: 1.172
# Epoch: 21 Progress: 21% Loss: 1.194
# Epoch: 21 Progress: 32% Loss: 1.178
# Epoch: 21 Progress: 42% Loss: 1.131
# Epoch: 21 Progress: 53% Loss: 1.100
# Epoch: 21 Progress: 64% Loss: 1.108
# Epoch: 21 Progress: 74% Loss: 1.121
# Epoch: 21 Progress: 85% Loss: 1.111
# Epoch: 21 Progress: 96% Loss: 1.120
#
# Epoch:  21  Train Loss:  1.117 Train Acc: 0.52589
# Val loss: 1.024 Val Acc 0.49938
#
# Epoch: 22 Progress:  0% Loss: 4.562
# Epoch: 22 Progress: 11% Loss: 1.186
# Epoch: 22 Progress: 21% Loss: 1.187
# Epoch: 22 Progress: 32% Loss: 1.181
# Epoch: 22 Progress: 42% Loss: 1.166
# Epoch: 22 Progress: 53% Loss: 1.149
# Epoch: 22 Progress: 64% Loss: 1.139
# Epoch: 22 Progress: 74% Loss: 1.134
# Epoch: 22 Progress: 85% Loss: 1.120
# Epoch: 22 Progress: 96% Loss: 1.115
#
# Epoch:  22  Train Loss:  1.113 Train Acc: 0.52865
# Val loss: 0.997 Val Acc 0.49567
#
# Epoch: 23 Progress:  0% Loss: 0.032
# Epoch: 23 Progress: 11% Loss: 1.046
# Epoch: 23 Progress: 21% Loss: 1.136
# Epoch: 23 Progress: 32% Loss: 1.065
# Epoch: 23 Progress: 42% Loss: 1.066
# Epoch: 23 Progress: 53% Loss: 1.084
# Epoch: 23 Progress: 64% Loss: 1.099
# Epoch: 23 Progress: 74% Loss: 1.103
# Epoch: 23 Progress: 85% Loss: 1.105
# Epoch: 23 Progress: 96% Loss: 1.106
#
# Epoch:  23  Train Loss:  1.113 Train Acc: 0.52207
# Val loss: 0.984 Val Acc 0.52290
#
# Epoch: 24 Progress:  0% Loss: 1.992
# Epoch: 24 Progress: 11% Loss: 1.032
# Epoch: 24 Progress: 21% Loss: 1.037
# Epoch: 24 Progress: 32% Loss: 1.070
# Epoch: 24 Progress: 42% Loss: 1.089
# Epoch: 24 Progress: 53% Loss: 1.078
# Epoch: 24 Progress: 64% Loss: 1.080
# Epoch: 24 Progress: 74% Loss: 1.094
# Epoch: 24 Progress: 85% Loss: 1.098
# Epoch: 24 Progress: 96% Loss: 1.111
#
# Epoch:  24  Train Loss:  1.109 Train Acc: 0.53088
# Val loss: 0.995 Val Acc 0.51176
#
# Epoch: 25 Progress:  0% Loss: 0.017
# Epoch: 25 Progress: 11% Loss: 1.034
# Epoch: 25 Progress: 21% Loss: 1.022
# Epoch: 25 Progress: 32% Loss: 1.083
# Epoch: 25 Progress: 42% Loss: 1.072
# Epoch: 25 Progress: 53% Loss: 1.108
# Epoch: 25 Progress: 64% Loss: 1.112
# Epoch: 25 Progress: 74% Loss: 1.102
# Epoch: 25 Progress: 85% Loss: 1.099
# Epoch: 25 Progress: 96% Loss: 1.097
#
# Epoch:  25  Train Loss:  1.103 Train Acc: 0.53236
# Val loss: 0.981 Val Acc 0.53527
#
# Epoch: 26 Progress:  0% Loss: 9.215
# Epoch: 26 Progress: 11% Loss: 1.190
# Epoch: 26 Progress: 21% Loss: 1.109
# Epoch: 26 Progress: 32% Loss: 1.111
# Epoch: 26 Progress: 42% Loss: 1.108
# Epoch: 26 Progress: 53% Loss: 1.112
# Epoch: 26 Progress: 64% Loss: 1.116
# Epoch: 26 Progress: 74% Loss: 1.114
# Epoch: 26 Progress: 85% Loss: 1.103
# Epoch: 26 Progress: 96% Loss: 1.113
#
# Epoch:  26  Train Loss:  1.103 Train Acc: 0.53597
# Val loss: 0.998 Val Acc 0.54517
#
# Epoch: 27 Progress:  0% Loss: 1.051
# Epoch: 27 Progress: 11% Loss: 1.218
# Epoch: 27 Progress: 21% Loss: 1.217
# Epoch: 27 Progress: 32% Loss: 1.182
# Epoch: 27 Progress: 42% Loss: 1.123
# Epoch: 27 Progress: 53% Loss: 1.090
# Epoch: 27 Progress: 64% Loss: 1.114
# Epoch: 27 Progress: 74% Loss: 1.108
# Epoch: 27 Progress: 85% Loss: 1.098
# Epoch: 27 Progress: 96% Loss: 1.099
#
# Epoch:  27  Train Loss:  1.101 Train Acc: 0.54213
# Val loss: 1.012 Val Acc 0.51423
#
# Epoch: 28 Progress:  0% Loss: 0.049
# Epoch: 28 Progress: 11% Loss: 1.048
# Epoch: 28 Progress: 21% Loss: 1.133
# Epoch: 28 Progress: 32% Loss: 1.128
# Epoch: 28 Progress: 42% Loss: 1.113
# Epoch: 28 Progress: 53% Loss: 1.092
# Epoch: 28 Progress: 64% Loss: 1.095
# Epoch: 28 Progress: 74% Loss: 1.088
# Epoch: 28 Progress: 85% Loss: 1.083
# Epoch: 28 Progress: 96% Loss: 1.089
#
# Epoch:  28  Train Loss:  1.102 Train Acc: 0.52833
# Val loss: 0.982 Val Acc 0.53403
#
# Epoch: 29 Progress:  0% Loss: 0.133
# Epoch: 29 Progress: 11% Loss: 1.048
# Epoch: 29 Progress: 21% Loss: 1.084
# Epoch: 29 Progress: 32% Loss: 1.078
# Epoch: 29 Progress: 42% Loss: 1.092
# Epoch: 29 Progress: 53% Loss: 1.092
# Epoch: 29 Progress: 64% Loss: 1.098
# Epoch: 29 Progress: 74% Loss: 1.106
# Epoch: 29 Progress: 85% Loss: 1.105
# Epoch: 29 Progress: 96% Loss: 1.094
#
# Epoch:  29  Train Loss:  1.094 Train Acc: 0.54414
# Val loss: 0.994 Val Acc 0.51361
#
# Epoch: 30 Progress:  0% Loss: 0.277
# Epoch: 30 Progress: 11% Loss: 1.084
# Epoch: 30 Progress: 21% Loss: 1.126
# Epoch: 30 Progress: 32% Loss: 1.133
# Epoch: 30 Progress: 42% Loss: 1.094
# Epoch: 30 Progress: 53% Loss: 1.077
# Epoch: 30 Progress: 64% Loss: 1.065
# Epoch: 30 Progress: 74% Loss: 1.084
# Epoch: 30 Progress: 85% Loss: 1.084
# Epoch: 30 Progress: 96% Loss: 1.089
#
# Epoch:  30  Train Loss:  1.095 Train Acc: 0.54425
# Val loss: 1.007 Val Acc 0.50743

# %%
torch.save(text_only_gru,'models/text_only_gru')
